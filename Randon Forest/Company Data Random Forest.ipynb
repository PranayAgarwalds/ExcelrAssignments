# %% [markdown]
# ### Company Data Random Forest

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Company_Data.csv")

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
df.shape
# Out:
# (400, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
df.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
#Checking CoRelation  Pearson
df.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
#
#                   Age  Education
# Sales       -0.231815  -0.051955
# CompPrice   -0.100239   0.025197
# Income      -0.004670  -0.056855
# Advertising -0.004557  -0.033594
# Population  -0.042663  -0.106378
# Price       -0.102177   0.011747
# Age          1.000000   0.006488
# Education    0.006488   1.000000

# %%
df[df.corr()>80].sum() # No High Correlation Found between Features
# Out:
# Sales          0.0
# CompPrice      0.0
# Income         0.0
# Advertising    0.0
# Population     0.0
# Price          0.0
# ShelveLoc        0
# Age            0.0
# Education      0.0
# Urban            0
# US               0
# dtype: object

# %%
#Checking CoRelation using Spearman Rank 
df.corr(method ='spearman')
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.067639  0.155368     0.275396    0.041937 -0.407607
# CompPrice    0.067639   1.000000 -0.066029    -0.028589   -0.108904  0.541795
# Income       0.155368  -0.066029  1.000000     0.057809   -0.007395 -0.049111
# Advertising  0.275396  -0.028589  0.057809     1.000000    0.241933  0.035613
# Population   0.041937  -0.108904 -0.007395     0.241933    1.000000 -0.006022
# Price       -0.407607   0.541795 -0.049111     0.035613   -0.006022  1.000000
# Age         -0.236344  -0.108612  0.002594     0.005157   -0.041474 -0.118385
# Education   -0.034474   0.021278 -0.061347    -0.046220   -0.104593  0.024439
#
#                   Age  Education
# Sales       -0.236344  -0.034474
# CompPrice   -0.108612   0.021278
# Income       0.002594  -0.061347
# Advertising  0.005157  -0.046220
# Population  -0.041474  -0.104593
# Price       -0.118385   0.024439
# Age          1.000000   0.004458
# Education    0.004458   1.000000

# %%
df[df.corr(method ='spearman')>80].sum() # No correation Found
# Out:
# Sales          0.0
# CompPrice      0.0
# Income         0.0
# Advertising    0.0
# Population     0.0
# Price          0.0
# ShelveLoc        0
# Age            0.0
# Education      0.0
# Urban            0
# US               0
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler, OrdinalEncoder,LabelEncoder

df.select_dtypes(object).columns
obj_enc=df.select_dtypes(object).columns

# %%
oe=OrdinalEncoder()
df[obj_enc]=oe.fit_transform(df[obj_enc])
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 11 columns]

# %%
calcols=df.select_dtypes(object).columns
oe=OrdinalEncoder()
df[calcols]=oe.fit_transform(df[calcols])

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [400 rows x 11 columns]

# %%
from sklearn.ensemble import IsolationForest
iso=IsolationForest(random_state=10,contamination=0.03)
out=iso.fit_predict(df)

# %%
df["outliers"]=out
df["outliers"].value_counts()
# Out:
#  1    388
# -1     12
# Name: outliers, dtype: int64

# %%
#Dropping The ouliers and selecting the normal data
df=df[df["outliers"]== 1]
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US  outliers
# 0           17    1.0  1.0         1
# 1           10    1.0  1.0         1
# 2           12    1.0  1.0         1
# 3           14    1.0  1.0         1
# 4           13    1.0  0.0         1
# ..         ...    ...  ...       ...
# 395         14    1.0  1.0         1
# 396         11    0.0  1.0         1
# 397         18    1.0  1.0         1
# 398         12    1.0  1.0         1
# 399         16    1.0  1.0         1
#
# [388 rows x 12 columns]

# %%
df=df.drop(["outliers"],axis=1)

# %%
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [388 rows x 11 columns]

# %%
df["Sales"].min()
# Out:
# 1.42

# %%
df["Sales"].max()
# Out:
# 16.27

# %%
# Converting Taget columns from Regression To Categorical as mentioned
bins=[0,8,16.27]

sales_conversion=["Small","Large"]

df["Cat_Sales"]=pd.cut(df["Sales"],bins,labels=sales_conversion)
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120        0.0   42
# 1    11.22        111      48           16         260     83        1.0   65
# 2    10.06        113      35           10         269     80        2.0   59
# 3     7.40        117     100            4         466     97        2.0   55
# 4     4.15        141      64            3         340    128        0.0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128        1.0   33
# 396   6.14        139      23            3          37    120        2.0   55
# 397   7.41        162      26           12         368    159        2.0   40
# 398   5.94        100      79            7         284     95        0.0   50
# 399   9.71        134      37            0          27    120        1.0   49
#
#      Education  Urban   US Cat_Sales
# 0           17    1.0  1.0     Large
# 1           10    1.0  1.0     Large
# 2           12    1.0  1.0     Large
# 3           14    1.0  1.0     Small
# 4           13    1.0  0.0     Small
# ..         ...    ...  ...       ...
# 395         14    1.0  1.0     Large
# 396         11    0.0  1.0     Small
# 397         18    1.0  1.0     Small
# 398         12    1.0  1.0     Small
# 399         16    1.0  1.0     Large
#
# [388 rows x 12 columns]

# %%
df=df.drop(["Sales"],axis=1)
df
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US Cat_Sales
# 0           17    1.0  1.0     Large
# 1           10    1.0  1.0     Large
# 2           12    1.0  1.0     Large
# 3           14    1.0  1.0     Small
# 4           13    1.0  0.0     Small
# ..         ...    ...  ...       ...
# 395         14    1.0  1.0     Large
# 396         11    0.0  1.0     Small
# 397         18    1.0  1.0     Small
# 398         12    1.0  1.0     Small
# 399         16    1.0  1.0     Large
#
# [388 rows x 11 columns]

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0          138      73           11         276    120        0.0   42
# 1          111      48           16         260     83        1.0   65
# 2          113      35           10         269     80        2.0   59
# 3          117     100            4         466     97        2.0   55
# 4          141      64            3         340    128        0.0   38
# ..         ...     ...          ...         ...    ...        ...  ...
# 395        138     108           17         203    128        1.0   33
# 396        139      23            3          37    120        2.0   55
# 397        162      26           12         368    159        2.0   40
# 398        100      79            7         284     95        0.0   50
# 399        134      37            0          27    120        1.0   49
#
#      Education  Urban   US
# 0           17    1.0  1.0
# 1           10    1.0  1.0
# 2           12    1.0  1.0
# 3           14    1.0  1.0
# 4           13    1.0  0.0
# ..         ...    ...  ...
# 395         14    1.0  1.0
# 396         11    0.0  1.0
# 397         18    1.0  1.0
# 398         12    1.0  1.0
# 399         16    1.0  1.0
#
# [388 rows x 10 columns]

# %%
y
# Out:
# 0      Large
# 1      Large
# 2      Large
# 3      Small
# 4      Small
#        ...
# 395    Large
# 396    Small
# 397    Small
# 398    Small
# 399    Large
# Name: Cat_Sales, Length: 388, dtype: category
# Categories (2, object): ['Small' < 'Large']

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30, random_state=42)
xtrain.shape, xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((271, 10), (117, 10), (271,), (117,))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix

rfc=RandomForestClassifier()
rfc.fit(xtrain,ytrain)
ypred = rfc.predict(xtest)
  
    
print(classification_report(ytest,ypred))
print(rfc.score(xtrain,ytrain))
print(rfc.score(xtest,ytest))
# Out:
#               precision    recall  f1-score   support
#
#        Large       0.86      0.74      0.80        50
#        Small       0.82      0.91      0.87        67
#
#     accuracy                           0.84       117
#    macro avg       0.84      0.83      0.83       117
# weighted avg       0.84      0.84      0.84       117
#
# 1.0
# 0.8376068376068376

# %%
print(confusion_matrix(ytest,ypred))
# Out:
# [[37 13]
#  [ 6 61]]

# %%
param_grid = {
 'n_estimators': [25, 50, 100, 150,200,250,300,350],
 'max_features': ['sqrt', 'log2', None],
 'max_depth': [3, 6, 9],
 'max_leaf_nodes': [3, 6, 9],
}

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(RandomForestClassifier(),
param_grid=param_grid,cv=10)

grid_search.fit(xtrain,ytrain)
print(grid_search.best_estimator_)
# Out:
# RandomForestClassifier(max_depth=6, max_features='log2', max_leaf_nodes=9,
#                        n_estimators=150)

# %%
rfc=RandomForestClassifier(max_depth=6, max_features='log2', max_leaf_nodes=9,
                       n_estimators=150)
rfc.fit(xtrain,ytrain)
ypred = rfc.predict(xtest)
  
    
print(classification_report(ytest,ypred))
print(rfc.score(xtrain,ytrain))
print(rfc.score(xtest,ytest))
# Out:
#               precision    recall  f1-score   support
#
#        Large       0.89      0.66      0.76        50
#        Small       0.79      0.94      0.86        67
#
#     accuracy                           0.82       117
#    macro avg       0.84      0.80      0.81       117
# weighted avg       0.83      0.82      0.82       117
#
# 0.9003690036900369
# 0.8205128205128205
